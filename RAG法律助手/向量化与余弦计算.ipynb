# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 2. 初始化嵌入模型（使用轻量级中文模型）
embedding_model = HuggingFaceEmbeddings(model_name="D:\\AIProjects\\modelscope\\BAAI\\bge-base-zh-v1___5")



#直接计算两个文本的向量相似度
def calculate_text_similarity(text1, text2):
    emb1 = embedding_model.embed_query(text1)
    emb2 = embedding_model.embed_query(text2)
    print(emb1)
    print(emb2)
    # 计算余弦相似度（因为我们的嵌入已归一化，点积=余弦相似度）
    similarity = sum([a*b for a,b in zip(emb1, emb2)])
    print(f"\n文本1: '{text1}'\n文本2: '{text2}'\n余弦相似度: {similarity:.4f}")
    return similarity

# 3. 测试文本相似度计算
calculate_text_similarity("西红柿", "西瓜")
calculate_text_similarity("西红柿", "番茄")

# %%
# 获取文档的原始向量
embeddings = embedding_model.embed_documents(documents)
print(f"向量维度: {len(embeddings[0])}")  # bge-small-zh输出768维向量

# 获取查询的向量
query = "中国的动物"
query_vector = embedding_model.embed_query(query)
print(query_vector)

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# 批量计算文档间相似度矩阵
embeddings_array = np.array(embeddings)
sim_matrix = cosine_similarity(embeddings_array)

print("\n文档间相似度矩阵:")
print(sim_matrix.round(2))
